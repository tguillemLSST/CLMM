# %% [markdown]
# # Comparing CLMM to NumCosmo
# This notebook compares `CLMM` to `NumCosmo`.

# %%
import numpy as np
import cluster_toolkit as ct
from astropy import constants, cosmology, units

# %%
# For NumCosmo
import gi
gi.require_version('NumCosmo', '1.0')
gi.require_version('NumCosmoMath', '1.0')
from gi.repository import NumCosmo as Nc
from gi.repository import NumCosmoMath as Ncm

# %%
import sys
from clmm import modeling as pp

# %% [markdown]
# ## Configuration

# %% [markdown]
# ### Cosmology

# %%
# If CCL is installed, define a CCL cosmology object
# import pyccl as ccl
# cosmo_ccl = ccl.Cosmology(Omega_c=0.27, Omega_b=0.045, h=0.67, A_s=2.1e-9, n_s=0.96)

# If CCL is not installed, use astropy instead with the following lines
from astropy.cosmology import FlatLambdaCDM
astropy_cosmology_object = FlatLambdaCDM(H0=70, Om0=0.27, Ob0=0.045)
cosmo_ccl = pp.cclify_astropy_cosmo(astropy_cosmology_object)

# %% [markdown]
# ### Cluster/source config

# %%
# Select density profile and profile parametrization options
density_profile_parametrization = 'nfw'
mass_Delta            = 200    # Mass defintion: mean matter density
cluster_mass          = 1.0e15 # Msun / h
cluster_concentration = 4.0
z_max                 = 3.0
z_cluster             = 1.0
z_source              = 2.0

# %% [markdown]
# ### Vectors for inputs

# %%
z_a = np.linspace (0.01, 3.0, 1000)
a_a = 1.0 / (1.0 + z_a)
r3d = np.logspace(-2, 2, 100)

# %% [markdown]
# ### NumCosmo
# Pass configs to `NumCosmo`

# %%
#########################
# Initializing NumCosmo #
#########################
Ncm.cfg_init ()

##################
# Set Cosmology ##
##################
cosmo = Nc.HICosmo.new_from_name (Nc.HICosmo, "NcHICosmoDEXcdm")
cosmo.omega_x2omega_k ()

cosmo.props.w  = -1.0
cosmo.props.H0 = cosmo_ccl['H0']

cosmo.param_set_by_name ("H0",     cosmo_ccl['H0'])
cosmo.param_set_by_name ("Omegab", cosmo_ccl['Omega_b'])
cosmo.param_set_by_name ("Omegac", cosmo_ccl['Omega_c'])
cosmo.param_set_by_name ("w",      -1.0)
cosmo.param_set_by_name ("Omegak",  0.0)
cosmo.param_set_by_name ("Tgamma0", 0.0)

##########################
# Config Cluster/Source ##
##########################

# Correction factor for the critical mass density 
# NumCosmo uses the gravitational constant value, G, from CODATA 2018. 
# cluster_toolkit defines a macro for rho_c, which provides a different value in comparison to NumCosmo.
# This correction factor is applied to the cluster mass value.
cor_factor = 2.77533742639e+11 * pp._patch_zevolution_cluster_toolkit_rho_m (1.0, 0.0) / Ncm.C.crit_mass_density_h2_solar_mass_Mpc3 () # 2.77533742639e+11 / Ncm.C.crit_mass_density_h2_solar_mass_Mpc3 ()
print ("cor_factor % 22.15g" % cor_factor)

# NumCosmo Density profile
dp              = Nc.DensityProfileNFW.new (Nc.DensityProfileMassDef.MEAN, mass_Delta)
dp.props.MDelta = cluster_mass / cor_factor / cosmo.h ()
dp.props.c      = cluster_concentration

dist = Nc.Distance.new (z_max)
smd  = Nc.WLSurfaceMassDensity.new (dist)

smd.prepare (cosmo)
# Out:
# cor_factor      0.999743514418463

# %% [markdown]
# ## Comparisons

# %% [markdown]
# ### Function to make automatic comparisons

# %%
import pylab as plt
def compare(x, y_clmm, y_nc, x_name='x', y_name='func', subplots_pars={'figsize':(6, 4)}):
    clmm_name, nc_name = '%s_{clmm}'%y_name, '%s_{nc}'%y_name
    diff = y_nc/y_clmm - 1.
    print('rel diff min: %e\nrel diff max: %e'%(min(abs(diff)), max(abs(diff))))
    fig, axs = plt.subplots(2, sharex=True, **subplots_pars)
    fig.subplots_adjust(hspace=0)
    
    axs[0].plot(x, y_clmm, label='clmm', lw=3)
    axs[0].plot(x, y_nc, label='nc')
    axs[1].plot(x, diff, c='r')
    axs[1].axhline(0, ls=':', c='0', lw=.5)

    axs[0].legend()
    axs[0].set_ylabel('$%s$'%y_name)
    axs[1].set_xlabel('$%s$'%x_name)
    axs[1].set_ylabel('$%s/%s-1$'%(nc_name, clmm_name))
    
    return fig, axs

# %% [markdown]
# ### Quick test of all modeling function

# %%
Da_a    = pp.angular_diameter_dist_a1a2 (cosmo_ccl, a_a)
nc_Da_a = np.array ([dist.angular_diameter (cosmo, z) * cosmo.RH_Mpc () * 1.0e6 for z in  z_a]) * cosmo.h ()

fig, axs = compare(z_a, Da_a, nc_Da_a, x_name='redshift', y_name='D_a(z)')
axs[0].set_yscale('log')
# Out:
# rel diff min: 1.165734e-14
# rel diff max: 5.757606e-09

# %%
rho    = pp.get_3d_density (r3d, mdelta=cluster_mass, cdelta=cluster_concentration,
                            z_cl = z_cluster, cosmo = cosmo_ccl, delta_mdef = mass_Delta)
nc_rho = np.array ([dp.eval_density (cosmo, r3d_i / cosmo.h (), z_cluster) * cor_factor / cosmo.h2 ()
                        for r3d_i in r3d])
#print (nc_rho / rho - 1.0)

fig, axs = compare (r3d, rho, nc_rho, x_name='radius [mpc]', y_name='\\rho')
axs[0].set_xscale('log')
# Out:
# rel diff min: 1.332268e-15
# rel diff max: 2.836509e-12

# %%
Sigma    = pp.predict_surface_density(r3d, cluster_mass, cluster_concentration, z_cl=z_cluster,
                                      cosmo=cosmo_ccl, delta_mdef=mass_Delta, 
                                      halo_profile_model='nfw')
nc_Sigma = np.array ([smd.sigma (dp, cosmo, r3d_i / cosmo.h (),
                                     z_cluster) * cor_factor / cosmo.h () / 1.0e12
                          for r3d_i in r3d])

fig, axs = compare(r3d, Sigma, nc_Sigma, x_name='radius [mpc]', y_name='\\Sigma')
axs[0].set_xscale('log')
# Out:
# rel diff min: 2.924283e-10
# rel diff max: 5.382559e-10

# %%
DeltaSigma    = pp.predict_excess_surface_density(r3d, cluster_mass, cluster_concentration,
                                                  z_cl=z_cluster, cosmo=cosmo_ccl, delta_mdef=mass_Delta, 
                                                  halo_profile_model='nfw')
nc_SigmaMean  = np.array ([smd.sigma_mean (dp, cosmo, r3d_i / cosmo.h (),
                                               z_cluster) * cor_factor / cosmo.h () / 1.0e12
                               for r3d_i in r3d])
nc_DeltaSigma = nc_SigmaMean - nc_Sigma

fig, axs = compare(r3d, DeltaSigma, nc_DeltaSigma, x_name='radius [mpc]', y_name=r'\Delta\Sigma')
axs[0].set_xscale('log')
# Out:
# rel diff min: 1.517420e-10
# rel diff max: 1.734521e-09

# %%
Sigmac = pp.get_critical_surface_density(cosmo_ccl, z_cluster=z_cluster, z_source=z_source)
nc_Sigmac = smd.sigma_critical (cosmo, z_source, z_cluster, z_cluster) * cor_factor / 1.0e12 / cosmo.h ()

print (Sigmac, nc_Sigmac, Sigmac / nc_Sigmac - 1.0)
# Out:
# 3840.8529684534606 3840.852968158885 7.669531676413044e-11

# %%
gammat    = pp.predict_tangential_shear(r3d, mdelta=cluster_mass, cdelta=cluster_concentration, z_cluster=z_cluster, 
                                        z_source=z_source, cosmo=cosmo_ccl, delta_mdef=mass_Delta, 
                                        halo_profile_model='nfw', z_src_model='single_plane')

nc_gammat = np.array ([smd.shear (dp, cosmo, r3d_i / cosmo.h (), z_source, z_cluster, z_cluster) for r3d_i in r3d])

fig, axs = compare(r3d, gammat, nc_gammat, x_name='radius [mpc]', y_name=r'{\gamma_t}')
axs[0].set_xscale('log')
# Out:
# rel diff min: 2.284373e-10
# rel diff max: 1.811216e-09

# %%
kappa = pp.predict_convergence(r3d, mdelta=cluster_mass, cdelta=cluster_concentration, 
                               z_cluster=z_cluster, z_source=z_source,
                               cosmo=cosmo_ccl, delta_mdef=mass_Delta, 
                               halo_profile_model='nfw', 
                               z_src_model='single_plane')

nc_kappa = np.array ([smd.convergence (dp, cosmo, r3d_i / cosmo.h (), z_source, z_cluster, z_cluster) for r3d_i in r3d])

fig, axs = compare(r3d, kappa, nc_kappa, x_name='radius [mpc]', y_name=r'\kappa')
axs[0].set_xscale('log')
# Out:
# rel diff min: 3.691234e-10
# rel diff max: 6.149512e-10

# %%
gt = pp.predict_reduced_tangential_shear(r3d, mdelta=cluster_mass, cdelta=cluster_concentration, 
                                         z_cluster=z_cluster, z_source=z_source, cosmo=cosmo_ccl, delta_mdef=mass_Delta, 
                                         halo_profile_model='nfw', z_src_model='single_plane')
# Recomputing from corrected gammat and kappa due to bug in kappa and gammat
# The corretion factor originating from differences in G is now applied to CLMM

nc_gt = nc_gammat / (1 - nc_kappa)

# To use the actual NumCosmo function, gt must be corrected by
#gt    = gammat / (cor_factor - kappa)
#nc_gt = np.array ([smd.reduced_shear (dp, cosmo, r3d_i / cosmo.h (), z_source, z_cluster, z_cluster) for r3d_i in r3d])

print (gt[0], nc_gt[0])

fig, axs = compare(r3d, gt, nc_gt, x_name='radius [mpc]', y_name=r'{g_t}')
axs[0].set_xscale('log')
axs[0].set_yscale('symlog')
# Out:
# -0.409925738728931 -0.40992573873571697
# rel diff min: 1.655409e-11
# rel diff max: 2.119496e-08

# %% [markdown]
# ### Save the numcosmo outputs

# %%
np.savetxt('radial_profiles.txt',
           np.array([r3d,  nc_rho, nc_Sigma, nc_DeltaSigma, nc_gammat, nc_kappa, nc_gt]).T,
           header='r3d  rho Sigma DeltaSigma gammat kappa gt')

# %%
np.savetxt('angular_diameter_distance.txt',
           np.array([a_a, z_a, nc_Da_a]).T,
           header='a_a z_a Da_a')

# %%
config_dict = {'dl': dist.angular_diameter (cosmo, z_cluster) * cosmo.RH_Mpc () * 1.0e6 * cosmo.h (),
               'z_source': z_source,
               'cluster_mass': cluster_mass,
               'G[m3/km.s2]': Ncm.C.G(),
               'nc_cor_factor': cor_factor,
               'aexp_cluster': 1./(1.+z_cluster),
               'density_profile_parametrization': density_profile_parametrization,
               'ds': dist.angular_diameter (cosmo, z_source) * cosmo.RH_Mpc () * 1.0e6 * cosmo.h (),
               'cosmo_Ob0': cosmo_ccl['Omega_b'],
               'aexp_source': 1./(1.+z_source),
               'dsl': 456254145.7550621,
               'z_cluster': z_cluster,
               'mass_Delta': mass_Delta,
               'lightspeed[km/s]': Ncm.C.c()/1000.,
               'cosmo_H0': cosmo_ccl['H0'],
               'cluster_concentration': cluster_concentration,
               'cosmo_Om0': cosmo_ccl['Omega_c'] + cosmo_ccl['Omega_b'],
               'nc_Sigmac': nc_Sigmac,
               'Msun[kg]': Ncm.C.mass_solar(),
               'pc_to_m': Ncm.C.pc()}

#import json
#with open('config.json', 'w') as fp:
#    json.dump(config_dict, fp)
